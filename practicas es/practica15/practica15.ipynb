# %%
from bs4 import BeautifulSoup
import requests
import csv

class Product:
    def __init__(self, name, data):
        self.name = name
        self.data = data

class WebScraper:
    def __init__(self, url):
        self.url = url
        self.products = []

    def scrape_data(self):
        html_text = requests.get(self.url).text
        soup = BeautifulSoup(html_text, 'lxml')
        product_list = soup.find_all('div', class_='ui-outputpanel ui-widget item-detail')

        for product_lists in product_list:
            product_name = product_lists.find('span', class_='tituloitemSedeCEO').text.strip()
            product_data = product_lists.find('div', class_='ui-outputpanel ui-widget infocontenido').text.replace(' ', ' ').strip()
            product = Product(product_name, product_data)
            self.products.append(product)

    def export_to_csv(self, filename='output.csv'):
        with open(filename, 'w', newline='', encoding='utf-8') as csv_file:
            csv_writer = csv.writer(csv_file)
            csv_writer.writerow(['Index', 'Product Name', 'Product Data'])
            for idx, product in enumerate(self.products, start=1):
                csv_writer.writerow([idx, product.name, product.data])
        print(f"Exportación completa. Se ha creado el archivo '{filename}'.")

    def import_and_process(self, filename='output.csv'):
        try:
            with open(filename, 'r', encoding='utf-8') as csv_file:
                csv_reader = csv.reader(csv_file)
                next(csv_reader)  # Salta la cabecera
                for row in csv_reader:
                    idx, product_name, product_data = row
                    product = Product(product_name, product_data)
                    self.products.append(product)
                    print(f'#{idx}\nName: {product_name} {product_data}\n{"-"*70}')
        except FileNotFoundError:
            print(f"El archivo '{filename}' no existe. Por favor, exporta los datos antes de importar.")

# Uso de la clase WebScraper
scraper = WebScraper('https://portal.siges.sv/pp/sedes')
scraper.scrape_data()
scraper.export_to_csv()
scraper.import_and_process()
# Out:
# Exportación completa. Se ha creado el archivo 'output.csv'.
# #1
# Name: CENTRO ESCOLAR "CANTON  EL CERRO BONITO" Código:13064
#
# Dirección:CANTON CERRO BONITO, SAN MIGUEL., SAN MIGUEL, SAN MIGUEL.
#
# Contactos:
# ----------------------------------------------------------------------
# #2
# Name: CENTRO ESCOLAR MARCO RENE REVELO Código:90002
#
# Dirección:CENTRO PENAL APANTEOS, SANTA ANA, SANTA ANA.
#
# Contactos:2484-2800
# ----------------------------------------------------------------------
# #3
# Name: CENTRO ESCOLAR CANTÓN SANTA RITA ALMENDRO Código:86376
#
# Dirección:CANTON SANTA RITA ALMENDRO, J%2f SANTIAGO NONUALCO, LA PAZ, SANTIAGO NONUALCO, LA PAZ.
#
# Contactos:
# ----------------------------------------------------------------------
# #4
# Name: CENTRO ESCOLAR CASERÍO CHICUMA, CANTÓN EL GAVILÁN Código:66091
#
# Dirección:CASERIO CHICUMA, C%2f EL GAVILAN, J%2f NUEVA CONCEPCION, CHALATENANGO, NUEVA CONCEPCION, CHALATENANGO.
#
# Contactos:
# ----------------------------------------------------------------------
# #5
# Name: CENTRO ESCOLAR "DE LA COLONIA SANTA MARTA" Código:10738
#
# Dirección:4ª CALLE ORIENTE NO. 2-6, COLONIA SANTA MARTA,, SONSONATE, SONSONATE.
#
# Contactos:2451-1661
# ----------------------------------------------------------------------
# #6
# Name: COMPLEJO EDUCATIVO "TALNIQUE" Código:11276
#
# Dirección:CALLE AL CANTON LOS SITIOS FRENTE A FINCA MATAZANO, J/ TALNIQUE, LA LIBERTAD, TALNIQUE, LA LIBERTAD.
#
# Contactos:78565190
# ----------------------------------------------------------------------
# #7
# Name: COMPLEJO EDUCATIVO DE EREGUAYQUÍN Código:12534
#
# Dirección:5 A. AVENIDA NORTE BARRIO LA PARROQUIA EREGUAYQUIN, EREGUAYQUIN, USULUTAN.
#
# Contactos:2627 6131
# ----------------------------------------------------------------------
# #8
# Name: COMPLEJO EDUCATIVO "COLONIA SAN FELIPE" Código:11390
#
# Dirección:COLONIA SAN FELIPE POLIGONO "B" N° 40, CANTON SAN BARTOLO, ILOPANGO, SAN SALVADOR, ILOPANGO, SAN SALVADOR.
#
# Contactos:22962748
# ----------------------------------------------------------------------
# #9
# Name: CENTRO ESCOLAR "DOCTOR DAVID TURCIOS". Código:13170
#
# Dirección:BO. CONCEPCION J/ CHILANGA, MORAZAN, CHILANGA, MORAZAN.
#
# Contactos:26593025
# ----------------------------------------------------------------------
# #10
# Name: CENTRO ESCOLAR CASERÍO SAN ISIDRO, CANTÓN EL TANQUE Código:62012
#
# Dirección:CASERIO SAN ISIDRO, C%2f EL TANQUE, J%2f CHALCHUAPA, SANTA ANA, CHALCHUAPA, SANTA ANA.
#
# Contactos:72870364
# ----------------------------------------------------------------------
# #11
# Name: CENTRO ESCOLAR CANTÓN JOYA ANCHA ARRIBA Código:80136
#
# Dirección:CANTON JOYA ANCHA ARRIBA, J%2fSANTA ELENA, USULUTAN, SANTA ELENA, USULUTAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #12
# Name: CENTRO ESCOLAR " JUAN RAMON JIMENEZ " Código:11174
#
# Dirección:FINAL 1A. AVENIDA SUR COLONIA LAS CRUCITAS, J%2f QUEZALTEPEQUE, LA LIBERTAD, QUEZALTEPEQUE, LA LIBERTAD.
#
# Contactos:78618944
# ----------------------------------------------------------------------
# #13
# Name: CENTRO ESCOLAR "CANTON MONTE ALEGRE" Código:10384
#
# Dirección:COLONIA SAN JUAN KM.74 CARRETERA HACIA CHALCHUAPA, SAN SEBASTIAN SALITRILLO, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #14
# Name: CENTRO ESCOLAR "CASERÍO EL ZOPE, CANTÓN AZACUALPA" Código:60213
#
# Dirección:CASERIO EL ZOPE, CANTON AZACUALPA, J%2f VICTORIA, CABAÑAS, VICTORIA, CABAÑAS.
#
# Contactos:76010333
# ----------------------------------------------------------------------
# #15
# Name: CENTRO ESCOLAR "SALVADOR ALEJANDRO MENÉNDEZ GARCÍA" Código:74029
#
# Dirección:CASERIO LOS MANGOS, CANTON EL PIMENTAL, SAN LUIS TALPA, LA PAZ, LOS MANGOS, SAN LUIS TALPA, LA PAZ.
#
# Contactos:79095555
# ----------------------------------------------------------------------
# #16
# Name: CENTRO ESCOLAR "EULOGIA RIVAS" Código:11809
#
# Dirección:2A. CALLE PONIENTE Y 1A. AVENIDA SUR NO. 2, COJUTEPEQUE, COJUTEPEQUE, CUSCATLAN.
#
# Contactos:2372-4507
# ----------------------------------------------------------------------
# #17
# Name: CENTRO ESCOLAR CASERÍO EL RUCIO, CANTÓN CALAVERA Código:86365
#
# Dirección:CASERIO EL RUCIO, CANTON CALAVERA, J/ CACAOPERA, MORAZAN, EL RUCIO, CACAOPERA, MORAZAN.
#
# Contactos:73525733
# ----------------------------------------------------------------------
# #18
# Name: INSTITUTO NACIONAL DE JUAYÚA Código:10644
#
# Dirección:Final Calle Monseñor Oscar Arnulfo Romero Oriente, JUAYUA, SONSONATE.
#
# Contactos:24522073
# ----------------------------------------------------------------------
# #19
# Name: CENTRO ESCOLAR  CANTÓN BARRANCONES Código:86096
#
# Dirección:CANTON BARRANCONES, J%2fPASAQUINA, LA UNION., PASAQUINA, LA UNIÓN.
#
# Contactos:
# ----------------------------------------------------------------------
# #20
# Name: CENTRO ESCOLAR  "DE SANTA CRUZ ANALQUITO" Código:11883
#
# Dirección:BARRIO EL CALVARIO , SANTA CRUZ ANALQUITO, SANTA CRUZ ANALQUITO, CUSCATLAN.
#
# Contactos:23799053
# ----------------------------------------------------------------------
# #21
# Name: CENTRO ESCOLAR  CASERÍO EL DESVÍO, CANTÓN SANTA CRUZ Código:60003
#
# Dirección:CASERIO EL DESVIO, C%2f SANTA CRUZ, J%2f AHUACHAPAN, AHUACHAPAN, AHUACHAPAN, AHUACHAPAN.
#
# Contactos:24013761
# ----------------------------------------------------------------------
# #22
# Name: CENTRO ESCOLAR "CASERIO COMUNIDAD SAN JUAN LA CEIBA, C. SAN ANTONIO" Código:60208
#
# Dirección:CASERIO COMUNIDAD SAN JUAN LA CEIBA, CANTON SAN ANTNIO, J%2f EL REFUGIO, EL REFUGIO, AHUACHAPAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #23
# Name: CENTRO ESCOLAR "CASERIO LOS ZELAYA, CANTÓN SAN FRANCISCO" Código:80172
#
# Dirección:CASERIO LOS ZELAYA, CANTON SAN FRANCISCO J%2f SANTA MARIA, USULUTAN, SANTA MARIA, USULUTAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #24
# Name: CENTRO ESCOLAR  CANTÓN SAN RAFAEL Código:11101
#
# Dirección:CANTON SAN RAFAEL, J%2f LA LIBERTAD, LA LIBERTAD, LA LIBERTAD, LA LIBERTAD.
#
# Contactos:79608442
# ----------------------------------------------------------------------
# #25
# Name: CENTRO ESCOLAR CASERÍO HACIENDA CANADA,  CANTÓN EL PRESIDIO Código:64098
#
# Dirección:CASERIO HDA. CANADA, CANTON EL PRESIDIO, J%2f SONSONATE, SONSONATE, SONSONATE, SONSONATE.
#
# Contactos:
# ----------------------------------------------------------------------
# #26
# Name: CENTRO ESCOLAR "CASERIO EL PILON,  CANTON LA JOYA" Código:12955
#
# Dirección:CASERIO EL PILON C%2f LA JOYA JURISDICCION DE SAN GERARDO, SAN GERARDO, SAN MIGUEL.
#
# Contactos:
# ----------------------------------------------------------------------
# #27
# Name: CENTRO ESCOLAR CASERÍO LAS HUATERAS, CANTÓN  EL ZAPOTE Código:80087
#
# Dirección:CASERIO LAS HUATERAS, CANTON EL ZAPOTE, J%2fJUCUARAN, USULUTAN, JUCUARAN, USULUTAN.
#
# Contactos:26620924
# ----------------------------------------------------------------------
# #28
# Name: CENTRO ESCOLAR  CASERÍO LOS RIVERA, CANTÓN  EL CAULOTE Código:64093
#
# Dirección:CASERÍO LOS RIVERA, CANTÓN EL CAULOTE, J/ SANTO DOMINGO DE GUZMÁN, SONSONATE, CASERÍO LOS RIVERA, SANTO DOMINGO DE GUZMAN, SONSONATE.
#
# Contactos:
# ----------------------------------------------------------------------
# #29
# Name: COMPLEJO EDUCATIVO "GENERAL RAFAEL OSORIO HIJO" Código:11945
#
# Dirección:CALLE MARCELINO DURAN BARRIO EL CENTRO, PARAISO DE OSORIO, LA PAZ.
#
# Contactos:23799665
# ----------------------------------------------------------------------
# #30
# Name: COMPLEJO EDUCATIVO "JOSÉ SIMEÓN CAÑAS" Código:11061
#
# Dirección:KILÓMETRO 2, DESVÍO A CHILTIUPÁN, CANTÓN JULUPE, CHILTIUPAN, LA LIBERTAD.
#
# Contactos:
# ----------------------------------------------------------------------
# #31
# Name: CENTRO ESCOLAR CASERÍO  SICAHUITE, CANTÓN SAN DIEGO" Código:82157
#
# Dirección:CASERIO EL SICAHUITE, CANTON SAN DIEGO, J%2f SAN ANTONIO DEL MOSCO, SAN MIGUEL, SAN ANTONIO, SAN MIGUEL.
#
# Contactos:
# ----------------------------------------------------------------------
# #32
# Name: CENTRO ESCOLAR " REPUBLICA DE ARGENTINA " Código:13545
#
# Dirección:BARRIO GUADALUPE CONTIGUO A ALCALDIA, SAN ALEJO, LA UNIÓN.
#
# Contactos:2649 0450
# ----------------------------------------------------------------------
# #33
# Name: COMPLEJO EDUCATIVO CASERÍO EL BARIO, CANTÓN PLATANARES Código:72057
#
# Dirección:CASERIO EL BARIO, CANTON PLATANARES, J%2fSUCHITOTO, CUSCATLAN, SUCHITOTO, CUSCATLAN.
#
# Contactos:70837467
# ----------------------------------------------------------------------
# #34
# Name: CENTRO ESCOLAR "CASERIO EL BOTADERO, CANTON EL ROBLE" Código:10029
#
# Dirección:CASERIO EL BOTADERO, C%2f EL ROBLE, EL BOTADERO, AHUACHAPAN, AHUACHAPAN.
#
# Contactos:78770132
# ----------------------------------------------------------------------
# #35
# Name: CENTRO ESCOLAR "CASERÍO SAN MARCOS, CANTÓN SANTO TOMAS" Código:86151
#
# Dirección:CASERIO SAN MARCOS, C%2f SANTO TOMAS, J%2f TEXISTEPEQUE, SANTA ANA, TEXISTEPEQUE, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #36
# Name: CENTRO ESCOLAR "CANTÓN EL JOBO" Código:10178
#
# Dirección:CANTON EL JOBO, TURIN, AHUACHAPAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #37
# Name: CENTRO ESCOLAR "LOMAS DE ALARCON" Código:10064
#
# Dirección:CANTON LOMAS DE ALARCON, ATIQUIZAYA, AHUACHAPAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #38
# Name: CENTRO ESCOLAR CASERÍO LAS PALMERAS, CANTÓN BELÉN Código:82017
#
# Dirección:CASERIO LAS PALMERAS, CANTON BELEN, J%2f CIUDAD BARRIOS, SAN MIGUEL, CIUDAD BARRIOS, SAN MIGUEL.
#
# Contactos:25641175
# ----------------------------------------------------------------------
# #39
# Name: CENTRO ESCOLAR "CASERÍO PIE DE LA CUESTA, CANTÓN SAN MIGUEL INGENIO" Código:62042
#
# Dirección:CASERIO PIE DE LA CUESTA, CANTON SAN MIGUEL INGENIO, J%2f METAPAN, SANTA ANA, METAPAN, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #40
# Name: CENTRO ESCOLAR CASERÍO SANTA ELENA, CANTÓN SANTA CATARINA Código:86418
#
# Dirección:CASERIO SANTA ELENA, CANTON SANTA CATARINA, J%2f SAN ESTEBAN CATARINA, SAN VICENTE, SAN ESTEBAN CATARINA, SAN VICENTE.
#
# Contactos:
# ----------------------------------------------------------------------
# #41
# Name: CENTRO ESCOLAR "LOTIFICACION CAMPO VERDE" Código:12082
#
# Dirección:LOTIFICACION CAMPO VERDE, CANTON LA LUCHA, ZACATECOLUCA, ZACATECOLUCA, LA PAZ.
#
# Contactos:
# ----------------------------------------------------------------------
# #42
# Name: CENTRO ESCOLAR " FINCA EL REFUGIO, CANTON EL CASTILLO " Código:11238
#
# Dirección:FINCA EL REFUGIO, CANTON EL CASTILLO, J%2f SAN JUAN OPICO, LA LIBERTAD, SAN JUAN OPICO, LA LIBERTAD.
#
# Contactos:75922512
# ----------------------------------------------------------------------
# #43
# Name: CENTRO ESCOLAR CANTÓN  EL ZAPOTE ARRIBA Código:70010
#
# Dirección:CANTON EL ZAPOTE ARRIBA, J%2f AYUTUXTEPEQUE, SAN SALVADOR, AYUTUXTEPEQUE, SAN SALVADOR.
#
# Contactos:
# ----------------------------------------------------------------------
# #44
# Name: CENTRO ESCOLAR COLONIA TRINIDAD, CANTÓN TECOMAPA Código:86482
#
# Dirección:COLONIA TRINIDAD, CANTON TECOMAPA, J%2fMETAPAN, SANTA ANA, METAPAN, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #45
# Name: CENTRO ESCOLAR CASERÍO LAS MARÍAS, CANTÓN LAS MARIAS Código:64039
#
# Dirección:CASERIO LAS MARIAS, CANTON LAS MARIAS, J%2f IZALCO, SONSONATE, IZALCO, SONSONATE.
#
# Contactos:
# ----------------------------------------------------------------------
# #46
# Name: CENTRO ESCOLAR "CANTON LAS DELICIAS" Código:13029
#
# Dirección:CANTON LAS DELICIAS, SAN MIGUEL, SAN MIGUEL, SAN MIGUEL.
#
# Contactos:2615 - 1224
# ----------------------------------------------------------------------
# #47
# Name: CENTRO ESCOLAR "CANTÓN MILINGO" Código:11777
#
# Dirección:CARRETERA TRONCAL DEL NORTE KM. 6 1%2f2, CIUDAD DELGADO, SAN SALVADOR, CIUDAD DELGADO, SAN SALVADOR.
#
# Contactos:21313575
# ----------------------------------------------------------------------
# #48
# Name: CENTRO ESCOLAR "HACIENDA HOJA DE SAL" Código:10111
#
# Dirección:HACIENDA HOJA DE SAL, C%2f GUAYAPA ARRIBA, JUJUTLA, AHUACHAPAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #49
# Name: CENTRO ESCOLAR  CASERÍO MANAGUA, CANTÓN SANTA ROSITA Código:86044
#
# Dirección:CASERIO MANAGUA, CANTON SANTA ROSITA, J%2fEL SAUCE, LA UNION, MANAGUA, EL SAUCE, LA UNIÓN.
#
# Contactos:
# ----------------------------------------------------------------------
# #50
# Name: COMPLEJO EDUCATIVO "HERBERT DE SOLA" Código:11378
#
# Dirección:CANTÓN LA CABAÑA,INGENIO LA CABAÑA, EL PAISNAL, SAN SALVADOR, EL PAISNAL, SAN SALVADOR.
#
# Contactos:60663668
# ----------------------------------------------------------------------
# #51
# Name: CENTRO ESCOLAR "CANTON LA QUESERA" Código:12178
#
# Dirección:CANTON LA QUESERA, KM. 58 CARRETERA A SENSUNTEPEQUE J%2fILOBASCO, ILOBASCO, CABAÑAS.
#
# Contactos:
# ----------------------------------------------------------------------
# #52
# Name: INSTITUTO NACIONAL DE EL COYOLITO Código:10991
#
# Dirección:CARRETERA TRONCAL DEL NORTE, KM. 49 1%2f2, CANTÓN EL COYOLITO, TEJUTLA, CHALATENANGO.
#
# Contactos:23530396
# ----------------------------------------------------------------------
# #53
# Name: CENTRO ESCOLAR CASERÍO LA SERENA, CANTÓN TULA Código:68106
#
# Dirección:CASERIO LA SERENA, C%2f TULA, J%2f SAN JOSE VILLANUEVA, LA LIBERTAD, SAN JOSE VILLANUEVA, LA LIBERTAD.
#
# Contactos:71634193
# ----------------------------------------------------------------------
# #54
# Name: ESCUELA DE EDUCACION PARVULARIA COMUNIDAD 7 DE SEPTIEMBRE Código:10223
#
# Dirección:COMUNIDAD 7 DE SEPTIEMBRE, PAJES 5, BLOCK E, (SAN BARTOLO TICZA), ILOPANGO, SAN SALVADOR.
#
# Contactos:
# ----------------------------------------------------------------------
# #55
# Name: CENTRO ESCOLAR " CANTON EL JOCOTILLO " Código:10789
#
# Dirección:C%2f EL JOCOTILLO, CONCEPCION QUEZALTEPEQUE, CHALATENANGO, CONCEPCION QUEZALTEPEQUE, CHALATENANGO.
#
# Contactos:
# ----------------------------------------------------------------------
# #56
# Name: CENTRO ESCOLAR "CANTON HATO NUEVO" Código:13041
#
# Dirección:CANTON HATO NUEVO, SAN MIGUEL., SAN MIGUEL, SAN MIGUEL.
#
# Contactos:70542224
# ----------------------------------------------------------------------
# #57
# Name: CENTRO ESCOLAR CASERÍO EL TIZATE, CANTÓN PATURLA Código:60303
#
# Dirección:CASERIO EL TIZATE, CANTON PATURLA J/JOATECA, MORAZAN, EL TIZATE, JOATECA, MORAZAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #58
# Name: CENTRO ESCOLAR "CASERIO CABALLERO, CANTON EL GRAMAL" Código:10872
#
# Dirección:CASERIO CABALLERO, C%2f EL GRAMAL, J%2f LA PALMA, CHALATENANGO, LA PALMA, CHALATENANGO.
#
# Contactos:
# ----------------------------------------------------------------------
# #59
# Name: CENTRO ESCOLAR "CASERIO SAN LUIS, CANTON LA MAGDALENA" Código:10253
#
# Dirección:CASERIO SAN LUIS, C%2f LA MAGDALENA, CHALCHUAPA, SANTA ANA.
#
# Contactos:79429150
# ----------------------------------------------------------------------
# #60
# Name: CENTRO ESCOLAR "CASERIO OJO DE AGUA" Código:12054
#
# Dirección:CASERIO OJO DE AGUA, C%2f EL PEDREGAL , EL ROSARIO,, EL ROSARIO, LA PAZ.
#
# Contactos:
# ----------------------------------------------------------------------
# #61
# Name: CENTRO ESCOLAR CANTÓN  JUAN HIGINIO Código:68062
#
# Dirección:CANTON JUAN HIGINIO, J%2f JAYAQUE, LA LIBERTAD, JAYAQUE, LA LIBERTAD.
#
# Contactos:78029227
# ----------------------------------------------------------------------
# #62
# Name: COMPLEJO EDUCATIVO "PROFESOR CARLOS LOBATO" Código:12117
#
# Dirección:FINAL 12 CALLE PONIENTE. Y 6a. AVENIDA. NTE. BARRIO. ANALCO, ZACATECOLUCA, ZACATECOLUCA, LA PAZ.
#
# Contactos:23344720
# ----------------------------------------------------------------------
# #63
# Name: ESCUELA DE EDUCACION ESPECIAL "DE LA COLONIA SANTA INES" Código:12997
#
# Dirección:COLONIA SANTA INES, CANTON EL ZAMORAN, SAN MIGUEL, SAN MIGUEL, SAN MIGUEL.
#
# Contactos:75607527
# ----------------------------------------------------------------------
# #64
# Name: CENTRO ESCOLAR CASERÍO LA LUCHITA Código:12087
#
# Dirección:KILOMETRO 62 CARRETERA AL LITORAL CASERIO LA LUCHITA, C%2f LA LUCHA, ZACATECOLUCA, ZACATECOLUCA, LA PAZ.
#
# Contactos:77669869
# ----------------------------------------------------------------------
# #65
# Name: CENTRO ESCOLAR CANTÓN EL LIMO Código:60033
#
# Dirección:CANTON EL LIMO, J%2fCONCEPCION DE ATACO, AHUACHAPAN, CONCEPCION DE ATACO, AHUACHAPAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #66
# Name: CENTRO ESCOLAR "PRESBÍTERO FERNANDO H. SAN GERMAN" Código:10737
#
# Dirección:AVENIDA CENTRAL COLONIA 14 DE DICIEMBRE, SONSONATE, SONSONATE.
#
# Contactos:76402735
# ----------------------------------------------------------------------
# #67
# Name: CENTRO ESCOLAR " COLONIA ESCALANTE " Código:11760
#
# Dirección:COLONIA ESCALANTE, CANTON EL ARENAL, CIUDAD DELGADO, SAN SALVADOR, CIUDAD DELGADO, SAN SALVADOR.
#
# Contactos:
# ----------------------------------------------------------------------
# #68
# Name: CENTRO ESCOLAR "CASERIO EL CEDRAL, CANTON MIRAFLORES" Código:13009
#
# Dirección:CASERIO EL CEDRAL. C%2fMIRAFLORES, SAN MIGUEL, SAN MIGUEL.
#
# Contactos:78880059
# ----------------------------------------------------------------------
# #69
# Name: CENTRO ESCOLAR  CANTÓN  SAN MARCOS JIBOA Código:74031
#
# Dirección:CANTON SAN MARCOS JIBOA, J%2f SAN LUIS TALPA, LA PAZ, SAN LUIS TALPA, LA PAZ.
#
# Contactos:
# ----------------------------------------------------------------------
# #70
# Name: CENTRO ESCOLAR CASERÍO VALLE NUEVO, CANTÓN CUJUCUYO Código:86469
#
# Dirección:CASERIO VALLE NUEVO, CANTON CUJUCUYO, TEXISTEPEQUE, SANTA ANA, TEXISTEPEQUE, SANTA ANA.
#
# Contactos:2441-2241
# ----------------------------------------------------------------------
# #71
# Name: CENTRO ESCOLAR CASERÍO LA LOMA, CANTÓN EL TRANSITO 1 Código:86326
#
# Dirección:CASERIO LA LOMA, CANTON EL TRANSITO 1, J%2f TONACATEPEQUE, SAN SALVADOR, TONACATEPEQUE, SAN SALVADOR.
#
# Contactos:
# ----------------------------------------------------------------------
# #72
# Name: CENTRO ESCOLAR CANTÓN TRES CEIBAS ARRIBA Código:70009
#
# Dirección:CANTON TRES CEIBAS ARRIBA, J%2fAPOPA, SAN SALVADOR, APOPA, SAN SALVADOR.
#
# Contactos:
# ----------------------------------------------------------------------
# #73
# Name: CENTRO ESCOLAR CASERÍO LA CUMBRE, CANTÓN LOS NARANJOS Código:64055
#
# Dirección:CASERIO LA CUMBRE, CANTON LOS NARANJOS, J%2f JUAYUA, SONSONATE, JUAYUA, SONSONATE.
#
# Contactos:
# ----------------------------------------------------------------------
# #74
# Name: CENTRO ESCOLAR "FRAY MARTIN DE PORRES" Código:10069
#
# Dirección:CANTON ZUNCA, ATIQUIZAYA, AHUACHAPAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #75
# Name: CENTRO ESCOLAR "CANTON EL CONACASTE" Código:10226
#
# Dirección:CANTON EL CONACASTE, 3 KM AL PONIENTE DE COATEPEQUE COLONIA SANTA JULIA, COATEPEQUE, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #76
# Name: CENTRO ESCOLAR  CASERÍO EL MAGUEYAL, CANTÓN JIBOA Código:72046
#
# Dirección:CASERIO EL MAGUEYAL, CANTON JIBOA, J%2fSAN RAFAEL CEDROS, CUSCATLAN, SAN RAFAEL CEDROS, CUSCATLAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #77
# Name: CENTRO ESCOLAR CASERÍO SANTA ANITA, CANTÓN LA CEIBITA Código:82150
#
# Dirección:CASERIO SANTA ANITA, CANTON LA CEIBITA, J%2f CAROLINA, SAN MIGUEL, CAROLINA, SAN MIGUEL.
#
# Contactos:75964205
# ----------------------------------------------------------------------
# #78
# Name: CENTRO ESCOLAR CASERÍO EL CHARCAL, CANTÓN EL TECOMATAL Código:80177
#
# Dirección:CASERIO EL CHARCAL, CANTON EL TECOMATAL J%2f ESTANZUELAS, USULUTAN, ESTANZUELAS, USULUTAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #79
# Name: CENTRO ESCOLAR "COLONIA LAS LUPITAS" Código:10201
#
# Dirección:COLONIA LAS LUPITAS, CANTON LA JOYA, COATEPEQUE, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #80
# Name: CENTRO ESCOLAR " CANTON EL COLORADO " Código:13484
#
# Dirección:CANTON EL COLORADO, PASAQUINA, LA UNION, PASAQUINA, LA UNIÓN.
#
# Contactos:
# ----------------------------------------------------------------------
# #81
# Name: CENTRO ESCOLAR  CANTÓN EL TEJAR Código:86034
#
# Dirección:CANTON EL TEJAR, J%2fEL CARMEN, LA UNION., EL CARMEN, LA UNIÓN.
#
# Contactos:70297214
# ----------------------------------------------------------------------
# #82
# Name: CENTRO ESCOLAR  CANTÓN SANTA GERTRUDIS Código:78064
#
# Dirección:CANTON SANTA GERTRUDIS, J%2f SAN VICENTE, SAN VICENTE., SAN VICENTE, SAN VICENTE.
#
# Contactos:
# ----------------------------------------------------------------------
# #83
# Name: CENTRO ESCOLAR COLONIA GUADALUPE Código:10161
#
# Dirección:ASENTAMIENTO GUADALUPE, CANTON TIERRA COLORADA, SAN JULIAN, SONSONATE.
#
# Contactos:70172419
# ----------------------------------------------------------------------
# #84
# Name: CENTRO ESCOLAR " CANTON CUYUISCAT " Código:10327
#
# Dirección:CANTON CUYUISCAT, METAPAN, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #85
# Name: CENTRO ESCOLAR CASERÍO EL FRANCO, CANTÓN EL SALITRE Código:86179
#
# Dirección:CASERIO EL FRANCO, CANTON SALITRE, J%2f SAN JOSE GUAYABAL, CUSCATLAN, SAN JOSE GUAYABAL, CUSCATLAN.
#
# Contactos:
# ----------------------------------------------------------------------
# #86
# Name: CENTRO ESCOLAR "JOSE ALEJANDRO CABRERA" Código:10461
#
# Dirección:CANTON CAMONES, SANTA ANA, SANTA ANA.
#
# Contactos:
# ----------------------------------------------------------------------
# #87
# Name: CENTRO ESCOLAR CASERÍO EL CONACASTE, CANTÓN LOS MARTÍNEZ Código:66143
#
# Dirección:CASERIO EL CONACASTE, CANTON LOS MARTINEZ, J%2f TEJUTLA, CHALATENANGO, TEJUTLA, CHALATENANGO.
#
# Contactos:
# ----------------------------------------------------------------------
# #88
# Name: CENTRO ESCOLAR "CASERIO PIEDRA PARADA, CANTON EL AGUACATE" Código:12250
#
# Dirección:CASERIO PIEDRA PARADA, C%2fEL AGUACATE, J%2fSENSUNTEPEQUE., SENSUNTEPEQUE, CABAÑAS.
#
# Contactos:7535 2108
# ----------------------------------------------------------------------
# #89
# Name: INSTITUTO NACIONAL DE SESORI Código:13111
#
# Dirección:8A. CALLE ORIENTE, Nº 5, BARRIO EL CALVARIO,, SESORI, SAN MIGUEL.
#
# Contactos:26820607
# ----------------------------------------------------------------------
# #90
# Name: CENTRO ESCOLAR  CASERÍO EL PROGRESO, CANTÓN LA PUERTA Código:60160
#
# Dirección:COLONIA EL CHORIZO, CANTON LA PUERTA, J%2f ARMENIA, SONSONATE, ARMENIA, SONSONATE.
#
# Contactos:
# ----------------------------------------------------------------------
# #91
# Name: CENTRO ESCOLAR " BARRIO EL PROGRESO " Código:11735
#
# Dirección:BARRIO EL PROGRESO, AVENIDA PRINCIPAL N° 20, SOYAPANGO, SAN SALVADOR, SOYAPANGO, SAN SALVADOR.
#
# Contactos:22271790
# ----------------------------------------------------------------------
# #92
# Name: CENTRO ESCOLAR "CANTON EL PAJAL" Código:11969
#
# Dirección:CANTON EL PAJAL, SAN JUAN NONUALCO, LA PAZ, SAN JUAN NONUALCO, LA PAZ.
#
# Contactos:70499276
# ----------------------------------------------------------------------
# #93
# Name: CENTRO ESCOLAR "CANTON  EL CHILAMATE" Código:10977
#
# Dirección:CANTON EL CHILAMATE, SANTA RITA, CHALATENANGO, SANTA RITA, CHALATENANGO.
#
# Contactos:
# ----------------------------------------------------------------------
# #94
# Name: CENTRO ESCOLAR " CANTON EL SAUCE " Código:11515
#
# Dirección:RIVERA DEL LAGO DE ILOPANGO,CANTON EL SAUCE, SAN MARTIN, SAN SALVADOR, SAN MARTIN, SAN SALVADOR.
#
# Contactos:
# ----------------------------------------------------------------------
# #95
# Name: CENTRO ESCOLAR "LOS CERROS, CANTÓN LA CONCEPCIÓN" Código:60168
#
# Dirección:CASERIO LOS CERROS, CANTON LA CONCEPCION, TEJUTEPEQUE, ILOBASCO, TEJUTEPEQUE, CABAÑAS.
#
# Contactos:79853986
# ----------------------------------------------------------------------
# #96
# Name: COMPLEJO EDUCATIVO "CANTÓN LA FLOR" Código:11516
#
# Dirección:KM. 19 1%2f2 CARRETERA PANAMERICANA C%2fLA FLOR, SAN MARTIN, SAN SALVADOR, SAN MARTIN, SAN SALVADOR.
#
# Contactos:
# ----------------------------------------------------------------------
# #97
# Name: CENTRO ESCOLAR CASERÍO SAN NICOLÁS, CANTÓN LAS MARÍAS Código:86403
#
# Dirección:CASERIO SAN NICOLAS, CANTON LAS MARIAS, J%2f IZALCO, SONSONATE, IZALCO, SONSONATE.
#
# Contactos:
# ----------------------------------------------------------------------
# #98
# Name: ESCUELA DE EDUCACIÓN PARVULARIA "DE SAN SEBASTIÁN" Código:12391
#
# Dirección:BARRIO SAN ANTONIO, CALLE PRINCIPAL, SAN SEBASTIAN, SAN VICENTE.
#
# Contactos:23967644
# ----------------------------------------------------------------------
# #99
# Name: CENTRO ESCOLAR "CANTON  IZCATAL" Código:12208
#
# Dirección:CANTON IZCATAL J/SAN ISIDRO, SAN ISIDRO, CABAÑAS.
#
# Contactos:
# ----------------------------------------------------------------------
# #100
# Name: ESCUELA DE EDUCACION PARVULARIA " SAN PEDRO PERULAPAN " Código:11866
#
# Dirección:AVENIDA MORAZAN BARRIO EL CENTRO, SAN PEDRO PERULAPAN, SAN PEDRO PERULAPAN, CUSCATLAN.
#
# Contactos:73555548
# ----------------------------------------------------------------------
